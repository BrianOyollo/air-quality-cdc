# %%
import requests
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
town_cods = {
    "nairobi": (1.286389,36.817223),
    "mombasa": (-4.043477,39.668206)
}

# %%
for town,cods in town_cods.items():
    town = town
    lat = cods[0]
    long = cods[1]
    base_url = f"https://air-quality-api.open-meteo.com/v1/air-quality?latitude={lat}&longitude={long}&hourly=pm2_5,pm10,ozone,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,uv_index"
# Out:
# nairobi
# https://air-quality-api.open-meteo.com/v1/air-quality?latitude=1.286389&longitude=36.817223&hourly=pm2_5,pm10,ozone,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,uv_index
# mombasa
# https://air-quality-api.open-meteo.com/v1/air-quality?latitude=-4.043477&longitude=39.668206&hourly=pm2_5,pm10,ozone,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,uv_index

# %%
nairobi = "https://air-quality-api.open-meteo.com/v1/air-quality?latitude=-1.286389&longitude=36.817223&hourly=pm2_5,pm10,ozone,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,uv_index"
response = requests.get(nairobi)

# %%
from datetime import datetime,timezone
retrieval_time = datetime.now(timezone.utc).isoformat(timespec='minutes')

# %%
# check if the response is okay
response.status_code
# Out:
# 200

# %%
data = response.json()
hourly_data = data['hourly']
for time, pm2_5, pm10, ozone, carbon_monoxide, nitrogen_dioxide, sulphur_dioxide, uv_index in zip(
    hourly_data['time'],
    hourly_data['pm2_5'],
    hourly_data['pm10'],
    hourly_data['ozone'],
    hourly_data['carbon_monoxide'],
    hourly_data['nitrogen_dioxide'],
    hourly_data['sulphur_dioxide'],
    hourly_data['uv_index']
):
    print("----------------------------------------------")
    print(f"forecast_time: {time}")
    print(f"pm2_5: {pm2_5}")
    print(f"pm10: {pm10}")
    print(f"ozone: {ozone}")
    print(f"carbon_monoxide: {carbon_monoxide}")
    print(f"nitrogen_dioxide: {nitrogen_dioxide}")
    print(f"sulphur_dioxide: {sulphur_dioxide}")
    print(f"uv_index: {uv_index}")
    print(f"retrieval_time: {retrieval_time}")
# Out:
# ----------------------------------------------
# forecast_time: 2025-10-01T00:00
# pm2_5: 14.7
# pm10: 15.5
# ozone: 54.0
# carbon_monoxide: 299.0
# nitrogen_dioxide: 9.7
# sulphur_dioxide: 4.0
# uv_index: 0.0
# retrieval_time: 2025-10-01T07:23+00:00
# ----------------------------------------------
# forecast_time: 2025-10-01T01:00
# pm2_5: 16.0
# pm10: 16.9
# ozone: 48.0
# carbon_monoxide: 360.0
# nitrogen_dioxide: 11.5
# sulphur_dioxide: 4.5
# uv_index: 0.0
# retrieval_time: 2025-10-01T07:23+00:00
# ----------------------------------------------
# forecast_time: 2025-10-01T02:00
# pm2_5: 16.8
# pm10: 17.8
# ozone: 42.0
# carbon_monoxide: 453.0
# nitrogen_dioxide: 13.7
# sulphur_dioxide: 5.2
# uv_index: 0.0
# retrieval_time: 2025-10-01T07:23+00:00
# ----------------------------------------------
# forecast_time: 2025-10-01T03:00
# pm2_5: 18.5
# pm10: 19.5
# ozone: 44.0
# carbon_monoxide: 518.0
# nitrogen_dioxide: 14.4
# sulphur_dioxide: 6.1
# uv_index: 0.0
# ...

# %%
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# %%
uri = "mongodb://admin:admin123@localhost:27017/"

client = MongoClient(uri)
try:
    client.admin.command("ping")
    print("success")
except ConnectionFailure as e:
    print(e)
# Out:
# Could not reach any servers in [('mongodb', 27017)]. Replica set is configured with internal hostnames or IPs?, Timeout: 30s, Topology Description: <TopologyDescription id: 68dce02ecf98286006097a4a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
client.trials_db2
db = client['trials_db2']

# %%
db.create_collection('test_collection')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'trials_db2'), 'test_collection')

# %%
db.test_collection.insert_many(mongo_data)
# Out:
# InsertManyResult([ObjectId('68d7cb4205b05bf07d89cea1'), ObjectId('68d7cb4205b05bf07d89cea2'), ObjectId('68d7cb4205b05bf07d89cea3'), ObjectId('68d7cb4205b05bf07d89cea4'), ObjectId('68d7cb4205b05bf07d89cea5'), ObjectId('68d7cb4205b05bf07d89cea6'), ObjectId('68d7cb4205b05bf07d89cea7'), ObjectId('68d7cb4205b05bf07d89cea8'), ObjectId('68d7cb4205b05bf07d89cea9'), ObjectId('68d7cb4205b05bf07d89ceaa'), ObjectId('68d7cb4205b05bf07d89ceab'), ObjectId('68d7cb4205b05bf07d89ceac'), ObjectId('68d7cb4205b05bf07d89cead'), ObjectId('68d7cb4205b05bf07d89ceae'), ObjectId('68d7cb4205b05bf07d89ceaf'), ObjectId('68d7cb4205b05bf07d89ceb0'), ObjectId('68d7cb4205b05bf07d89ceb1'), ObjectId('68d7cb4205b05bf07d89ceb2'), ObjectId('68d7cb4205b05bf07d89ceb3'), ObjectId('68d7cb4205b05bf07d89ceb4'), ObjectId('68d7cb4205b05bf07d89ceb5'), ObjectId('68d7cb4205b05bf07d89ceb6'), ObjectId('68d7cb4205b05bf07d89ceb7'), ObjectId('68d7cb4205b05bf07d89ceb8'), ObjectId('68d7cb4205b05bf07d89ceb9'), ObjectId('68d7cb4205b05bf07d89
# ...

# %%
## create db
def create_db_and_collection(db_uri:str, mongo_db_name:str,mongo_collection_name:str):

    load_dotenv()

    # uri = "mongodb://admin:admin123@localhost:27017/" 
    # # if running inside docker, replace local with container name and vice versa

    # establish connection
    client = MongoClient(db_uri)

    # create db
    client.mongo_db_name

    # create collection
    db = client[mongo_db_name]
    db.create_collection(mongo_collection_name)

    return db

# %%
# extract data
def extract(location:str, cods:tuple)->list:
    lat = cods[0]
    long = cods[1]
    loc_data = []

    base_url = f"https://air-quality-api.open-meteo.com/v1/air-quality?latitude={lat}&longitude={long}&hourly=pm2_5,pm10,ozone,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,uv_index"
    response = requests.get(base_url)
    retrieval_time = datetime.now(timezone.utc).isoformat(timespec='minutes')
    data = response.json()
    hourly_data = data['hourly']
    for time, pm2_5, pm10, ozone, carbon_monoxide, nitrogen_dioxide, sulphur_dioxide, uv_index in zip(
        hourly_data['time'],
        hourly_data['pm2_5'],
        hourly_data['pm10'],
        hourly_data['ozone'],
        hourly_data['carbon_monoxide'],
        hourly_data['nitrogen_dioxide'],
        hourly_data['sulphur_dioxide'],
        hourly_data['uv_index']
    ):
        loc_data.append(
            {   
                "location":location,
                "retrieval_time": retrieval_time,
                "forecast_time":time,
                "pm2_5":pm2_5,
                "pm10":pm10,
                "ozone":ozone,
                "carbon_monoxide":carbon_monoxide,
                "nitrogen_dioxide":nitrogen_dioxide,
                "sulphur_dioxide":sulphur_dioxide,
                "uv_index":uv_index
            }
        )
    return loc_data

# %%
# load data
def load_data(db,mongo_collection_name:str, data:list[dict]):
    collection = db[str(mongo_collection_name)]
    collection.insert_many(data)

# %% [markdown]
# # ETL

# %%
# env variables
# db_uri = os.getenv('DB_URI')
mongo_db = os.getenv('MONGO_DB')
mongo_collection = os.getenv('MONGO_COLLECTION')
db_uri="mongodb://admin:admin123@localhost:27017/?replicaSet=rs0&authSource=admin" 

# load_data
town_cods = {
    "nairobi": (1.286389,36.817223),
    "mombasa": (-4.043477,39.668206),

}

# %%
# create db
print("creating dbs and collection")
db = create_db_and_collection(db_uri, mongo_db, mongo_collection)
# Out:
# creating dbs and collection
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[25], line 3
#       1 # create db
#       2 print("creating dbs and collection")
# ----> 3 db = create_db_and_collection(db_uri, mongo_db, mongo_collection)
#
# Cell In[20], line 17, in create_db_and_collection(db_uri, mongo_db_name, mongo_collection_name)
#      15 # create collection
#      16 db = client[mongo_db_name]
# ---> 17 db.create_collection(mongo_collection_name)
#      19 return db
#
# File ~/Documents/luxdev DE/capstone/.venv/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# ...

# %%
# extract data
mongo_data = []
for location, cods in town_cods.items():
    try:
        print('extracting data')
        data = extract(location, cods)
        mongo_data.extend(data)
    except Exception as e:
        print(e)
        continue

# load data
print("Loading data into mongodb...")
load_data(db, mongo_collection, mongo_data)
# Out:
# creating dbs and collections
# extracting data
# ...

# %% [markdown]
# # GENERATE Cassandra init.cql, source and sink json files

# %%
# generate connectors
import os
import json
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# generate_cassandra_schema.py

def generate_cassandra_init():
    schema = """
    CREATE KEYSPACE IF NOT EXISTS weather WITH REPLICATION = {
        'class': 'SimpleStrategy',
        'replication_factor': 1
    };

    USE weather;

    CREATE TABLE IF NOT EXISTS air_quality (
        forecast_time timestamp,
        retrieval_time timestamp,
        location text,
        pm2_5 double,
        pm10 double,
        ozone double,
        carbon_monoxide double,
        nitrogen_dioxide double,
        sulphur_dioxide double,
        uv_index double,
        PRIMARY KEY (location, forecast_time)
    );
    """

    # Write to a .cql file
    with open("weather_schema.cql", "w") as f:
        f.write(schema)

# %%
# source connector
def generate_source_connector():

    mongo_debezium_user_name = os.getenv("MONGO_DEBEZIUM_USER_NAME")
    mongo_debezium_user_password = os.getenv("MONGO_DEBEZIUM_USER_PASSWORD")

    mongodb_connection_string = f"mongodb://{mongo_debezium_user_name}:{mongo_debezium_user_password}@mongodb:27017/?replicaSet=rs0"

    source_connector = {
        "name": "mongo-connector",
        "config": {
            "connector.class": "io.debezium.connector.mongodb.MongoDbConnector",
            "tasks.max": "1",
            "mongodb.connection.string": "",
            "mongodb.user": "debezium",
            "mongodb.password": "debeziumPass123",
            "mongodb.authsource": "admin",
            "topic.prefix": "weather",
            "capture.scope": "deployment",
            "snapshot.mode": "initial",

            "transforms": "unwrap",
            "transforms.unwrap.type":"io.debezium.connector.mongodb.transforms.ExtractNewDocumentState",
            "transforms.unwrap.delete.tombstone.handling.mode":"drop",
            "transforms.unwrap.add.headers":"op"
        }
    }
    source_connector['config']['mongodb.connection.string']=mongodb_connection_string
    source_connector['config']['mongodb.user']=mongo_debezium_user_name
    source_connector['config']['mongodb.password']=mongo_debezium_user_password

    return source_connector
generate_source_connector()
# Out:
# {'name': 'mongo-connector',
#  'config': {'connector.class': 'io.debezium.connector.mongodb.MongoDbConnector',
#   'tasks.max': '1',
#   'mongodb.connection.string': 'mongodb://:@mongodb:27017/?replicaSet=rs0',
#   'mongodb.user': '',
#   'mongodb.password': '',
#   'mongodb.authsource': 'admin',
#   'topic.prefix': 'weather',
#   'capture.scope': 'deployment',
#   'snapshot.mode': 'initial',
#   'transforms': 'unwrap',
#   'transforms.unwrap.type': 'io.debezium.connector.mongodb.transforms.ExtractNewDocumentState',
#   'transforms.unwrap.delete.tombstone.handling.mode': 'drop',
#   'transforms.unwrap.add.headers': 'op'}}
